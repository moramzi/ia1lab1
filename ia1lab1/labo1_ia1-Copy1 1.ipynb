# %%
from pandas import read_csv


try :
    filename = 'BeansDataSet.csv'
    data = read_csv(filename)
    print(f"dataFrame\n-------\n{data}")
    
except Exception as e :
    print(f"une erreur s'est produite", e)
# Out:
# dataFrame
# -------
#     Channel Region  Robusta  Arabica  Espresso  Lungo  Latte  Cappuccino
# 0    Online  South    12669     9656      7561    214   2674        1338
# 1    Online  South     7057     9810      9568   1762   3293        1776
# 2    Online  South     6353     8808      7684   2405   3516        7844
# 3     Store  South    13265     1196      4221   6404    507        1788
# 4    Online  South    22615     5410      7198   3915   1777        5185
# ..      ...    ...      ...      ...       ...    ...    ...         ...
# 435   Store  South    29703    12051     16027  13135    182        2204
# 436   Store  South    39228     1431       764   4510     93        2346
# 437  Online  South    14531    15488     30243    437  14841        1867
# 438   Store  South    10290     1981      2232   1038    168        2125
# 439   Store  South     2787     1698      2510     65    477          52
#
# [440 rows x 8 columns]

# %% [markdown]
# # Assistant
# Bien sûr, je serais ravi de vous aider avec cela. Veuillez partager le code que vous souhaitez analyser afin que je puisse vous fournir une analyse détaillée.

# %% [markdown]
# # histogrammes

# %%
from matplotlib import pyplot
data.hist(figsize=(9,9))
pyplot.show()

# %% [markdown]
# # fonctions

# %%
data.plot(kind='density', layout=(4,4), subplots=True, sharex=False, sharey=False, figsize=(12,9))
pyplot.show()

# %% [markdown]
# #  boites a moustaches

# %%
data.plot(kind='box', layout=(4,5), subplots=True, sharex=False, sharey=False, figsize=(9,9))
pyplot.show()

# %% [markdown]
# #  correlation

# %%
print(f'Correlation \n------\n {data.corr().round(2)}')
# Out:
# Correlation
# ------
#              Robusta  Arabica  Espresso  Lungo  Latte  Cappuccino
# Robusta        1.00     0.10     -0.01   0.35  -0.10        0.24
# Arabica        0.10     1.00      0.73   0.12   0.66        0.41
# Espresso      -0.01     0.73      1.00  -0.04   0.92        0.21
# Lungo          0.35     0.12     -0.04   1.00  -0.13        0.39
# Latte         -0.10     0.66      0.92  -0.13   1.00        0.07
# Cappuccino     0.24     0.41      0.21   0.39   0.07        1.00
